# %%
# What is pandas.
# Panda is open-source library that deal with labbled data.

# why are use the pandas

# %%
# Create a 1D array
import numpy as np
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
import pandas as pd
p=pd.Series(a)
print(p)

sr=pd.Series(a,index=['a','b','c','d'])
print("Output is alphabatically format",sr)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32
# Output is alphabatically format a    1
# b    2
# c    3
# d    4
# dtype: int32

# %%
#Create a series from the dictionary.
import pandas as pd
info={
    "Nama":"Zuheb",
    "Course":"Data science",
    "Address":"Uttar Pradesh",
    "Duration":"4-months"
}

p=pd.Series(info)
print(p)
# Out:
# Nama                Zuheb
# Course       Data science
# Address     Uttar Pradesh
# Duration         4-months
# dtype: object

# %%
# Create an series from the set--> we cannot create 
s={10,20,30,40}
set=pd.Series(s)

print(set) #TypeERROR
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 s={10,20,30,40}
# ----> 2 s1=pd.Series(s)
#       3 print(s1)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\construction.py:642, in sanitize_array(data, index, dtype, copy, allow_2d)
#     633     return sanitize_array(
#     634         data,
#     635         index=index,
#    (...)
#     638         allow_2d=allow_2d,
#     639     )
#     641 else:
# --> 642     _sanitize_non_ordered(data)
# ...

# %%
# create a dataFrame from below list
import pandas as pd
l=[10,20,30,50,60]
df=pd.DataFrame(l)

print(df)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  50
# 4  60

# %%
import pandas as pd
l=[10,20,30,50,60]
df=pd.DataFrame(l,index=['a','b','c','d','e'],columns=['number'])

print(df)
# Out:
#    number
# a      10
# b      20
# c      30
# d      50
# e      60

# %%
#Create a dataframe from set of fruits.
f={"mango","Banana","apple","pineapple"}
df=pd.DataFrame(f)
print(df)
# Out:
#            0
# 0      apple
# 1      mango
# 2     Banana
# 3  pineapple

# %%
#create a df from tuple of numbers.
import pandas as pd
t=[1,2,4,5,6]
df=pd.DataFrame(t)

print(df)
# Out:
#    0
# 0  1
# 1  2
# 2  4
# 3  5
# 4  6

# %%
# create a df from dictionary.
import pandas as pd

details={
    "Code":"3211",
    "language":"Python",
    "course-fee":"32000"
}
df=pd.
